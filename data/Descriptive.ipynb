# %%
import pandas as pd

# %%
df = pd.read_csv('./dataset/full_preprocessed_data.csv')

# %%
df
# Out:
#      loan_id        date  amount  duration  payments  frequency  balance_mean  \
# 0       5314  1993-07-05   96396        12      8033          2  12250.000000
# 1       5316  1993-07-11  165960        36      4610          1  52083.859459
# 2       6863  1993-07-28  127080        60      2118          1  30060.954167
# 3       5325  1993-08-03  105804        36      2939          1  41297.480000
# 4       7240  1993-09-06  274740        60      4579          2  57188.211111
# ..       ...         ...     ...       ...       ...        ...           ...
# 323     6818  1996-12-12  155616        48      3242          1  44197.509884
# 324     5625  1996-12-15  222180        60      3703          1  55230.444068
# 325     6805  1996-12-21   45024        48       938          1  41994.907692
# 326     7233  1996-12-25  115812        36      3217          1  56646.516129
# 327     7308  1996-12-27  129408        24      5392          1  30869.781308
#
# ...
